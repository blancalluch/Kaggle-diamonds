# %%
import pandas as pd

# %%
diamonds=pd.read_csv("./input/data.csv")
diamonds.head()
# Out:
#    carat        cut color clarity  depth  table     x     y     z  price
# 0   2.26      Ideal     G     SI2   61.9   57.0  8.44  8.36  5.20  12831
# 1   2.43  Very Good     H     SI2   63.2   57.0  8.56  8.50  5.39  16170
# 2   0.80    Premium     F     SI2   61.0   57.0  6.03  6.01  3.67   2797
# 3   0.40      Ideal     F      I1   63.3   60.0  4.68  4.64  2.95    630
# 4   0.31      Ideal     G     VS2   61.6   55.0  4.39  4.37  2.70    698

# %%
print(diamonds.shape)
diamonds.dtypes
# Out:
# (40455, 10)
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# x          float64
# y          float64
# z          float64
# price        int64
# dtype: object

# %%
diamonds.cut.value_counts()
# Out:
# Ideal        16139
# Premium      10377
# Very Good     9101
# Good          3650
# Fair          1188
# Name: cut, dtype: int64

# %%
diamonds.color.value_counts()
# Out:
# G    8492
# E    7343
# F    7183
# H    6230
# D    5046
# I    4046
# J    2115
# Name: color, dtype: int64

# %%
diamonds.clarity.value_counts()
# Out:
# SI1     9767
# VS2     9147
# SI2     6909
# VS1     6157
# VVS2    3822
# VVS1    2740
# IF      1356
# I1       557
# Name: clarity, dtype: int64

# %%
diamonds.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %%
print(diamonds.shape)
diamonds=diamonds[(diamonds.x!=0) & (diamonds.y!=0) & (diamonds.z!=0)]
diamonds
# Out:
# (40455, 10)
#        carat        cut color clarity  depth  table     x     y     z  price
# 0       2.26      Ideal     G     SI2   61.9   57.0  8.44  8.36  5.20  12831
# 1       2.43  Very Good     H     SI2   63.2   57.0  8.56  8.50  5.39  16170
# 2       0.80    Premium     F     SI2   61.0   57.0  6.03  6.01  3.67   2797
# 3       0.40      Ideal     F      I1   63.3   60.0  4.68  4.64  2.95    630
# 4       0.31      Ideal     G     VS2   61.6   55.0  4.39  4.37  2.70    698
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 40450   1.11    Premium     H     SI1   62.8   61.0  6.63  6.56  4.14   5315
# 40451   0.73      Ideal     F     VS2   62.6   56.0  5.77  5.74  3.60   2762
# 40452   1.26  Very Good     I     VS1   59.2   60.0  7.09  7.02  4.18   6855
# 40453   0.72      Ideal     G     SI2   61.4   56.0  5.76  5.83  3.56   2297
# 40454   0.54    Premium     G     SI1   60.8   59.0  5.27  5.23  3.19   1356
#
# [40440 rows x 10 columns]

# %%
diamonds.eq(0).any()
# Out:
# carat      False
# cut        False
# color      False
# clarity    False
# depth      False
# table      False
# x          False
# y          False
# z          False
# price      False
# dtype: bool

# %%
diamonds.corr()
# Out:
#           carat     depth     table         x         y         z     price
# carat  1.000000  0.024387  0.180787  0.977856  0.946960  0.956441  0.921873
# depth  0.024387  1.000000 -0.296330 -0.028548 -0.032600  0.090613 -0.014452
# table  0.180787 -0.296330  1.000000  0.195812  0.182540  0.150994  0.125521
# x      0.977856 -0.028548  0.195812  1.000000  0.967457  0.970672  0.887228
# y      0.946960 -0.032600  0.182540  0.967457  1.000000  0.946432  0.861397
# z      0.956441  0.090613  0.150994  0.970672  0.946432  1.000000  0.863984
# price  0.921873 -0.014452  0.125521  0.887228  0.861397  0.863984  1.000000

# %%
diamonds.describe()
# Out:
#               carat         depth         table             x             y  \
# count  40440.000000  40440.000000  40440.000000  40440.000000  40440.000000
# mean       0.798141     61.748064     57.458687      5.732530      5.736279
# std        0.474132      1.432020      2.230629      1.120857      1.150923
# min        0.200000     43.000000     43.000000      3.730000      3.680000
# 25%        0.400000     61.000000     56.000000      4.710000      4.720000
# 50%        0.700000     61.800000     57.000000      5.700000      5.710000
# 75%        1.040000     62.500000     59.000000      6.540000      6.540000
# max        5.010000     79.000000     79.000000     10.740000     58.900000
#
#                   z         price
# count  40440.000000  40440.000000
# mean       3.540850   3937.746316
# std        0.706559   3998.852143
# min        1.410000    326.000000
# 25%        2.910000    949.000000
# 50%        3.530000   2407.000000
# 75%        4.040000   5330.250000
# ...

# %%
diamonds.describe(include='object')
# Out:
#           cut  color clarity
# count   40440  40440   40440
# unique      5      7       8
# top     Ideal      G     SI1
# freq    16136   8484    9766

# %%
car_50=diamonds.describe()['carat'][5]

# %%
diamonds.drop(columns=['y','x','z'],inplace=True)

# %%
diamonds
# Out:
#        carat        cut color clarity  depth  table  price
# 0       2.26      Ideal     G     SI2   61.9   57.0  12831
# 1       2.43  Very Good     H     SI2   63.2   57.0  16170
# 2       0.80    Premium     F     SI2   61.0   57.0   2797
# 3       0.40      Ideal     F      I1   63.3   60.0    630
# 4       0.31      Ideal     G     VS2   61.6   55.0    698
# ...      ...        ...   ...     ...    ...    ...    ...
# 40450   1.11    Premium     H     SI1   62.8   61.0   5315
# 40451   0.73      Ideal     F     VS2   62.6   56.0   2762
# 40452   1.26  Very Good     I     VS1   59.2   60.0   6855
# 40453   0.72      Ideal     G     SI2   61.4   56.0   2297
# 40454   0.54    Premium     G     SI1   60.8   59.0   1356
#
# [40440 rows x 7 columns]

# %%
def color_grouping(x):
    for k,v in changes.items():
        if x in v:
            x=k
            return x
    return x

# %%
d1=diamonds.copy()
d2=diamonds.copy()

# %%
changes={"DE_colors":["D","E"],"FGH_colors": ["F","G","H"],"IJ_colors":["I","J"]}

d1.color=d1.color.apply(color_grouping)

changes={"I1_clarity":["I1"],"S_clarity": ["SI2", "SI1"], "V_clarity":["VS2", "VS1", "VVS2", "VVS1"], "IF_clarity":["IF"]}

d1.clarity=d1.clarity.apply(color_grouping)

# %%
dummies=d1[['cut',"color","clarity"]]
d_dum=pd.get_dummies(dummies)
d1=d1.join(d_dum)
d1
# Out:
#        carat        cut       color     clarity  depth  table  price  \
# 0       2.26      Ideal  FGH_colors   S_clarity   61.9   57.0  12831
# 1       2.43  Very Good  FGH_colors   S_clarity   63.2   57.0  16170
# 2       0.80    Premium  FGH_colors   S_clarity   61.0   57.0   2797
# 3       0.40      Ideal  FGH_colors  I1_clarity   63.3   60.0    630
# 4       0.31      Ideal  FGH_colors   V_clarity   61.6   55.0    698
# ...      ...        ...         ...         ...    ...    ...    ...
# 40450   1.11    Premium  FGH_colors   S_clarity   62.8   61.0   5315
# 40451   0.73      Ideal  FGH_colors   V_clarity   62.6   56.0   2762
# 40452   1.26  Very Good   IJ_colors   V_clarity   59.2   60.0   6855
# 40453   0.72      Ideal  FGH_colors   S_clarity   61.4   56.0   2297
# 40454   0.54    Premium  FGH_colors   S_clarity   60.8   59.0   1356
#
#        cut_Fair  cut_Good  cut_Ideal  cut_Premium  cut_Very Good  \
# 0             0         0          1            0              0
# ...

# %%
d1.corr()
# Out:
#                        carat     depth     table     price  cut_Fair  \
# carat               1.000000  0.024387  0.180787  0.921873  0.088994
# depth               0.024387  1.000000 -0.296330 -0.014452  0.281230
# table               0.180787 -0.296330  1.000000  0.125521  0.123069
# price               0.921873 -0.014452  0.125521  1.000000  0.016297
# cut_Fair            0.088994  0.281230  0.123069  0.016297  1.000000
# cut_Good            0.032996  0.132410  0.178401 -0.000185 -0.054749
# cut_Ideal          -0.161787 -0.022161 -0.550310 -0.095193 -0.141693
# cut_Premium         0.117106 -0.196575  0.339819  0.095688 -0.102120
# cut_Very Good       0.008662  0.027040  0.117873  0.005112 -0.093704
# color_DE_colors    -0.199807 -0.032622 -0.000586 -0.139786 -0.024993
# color_FGH_colors    0.008625  0.005366 -0.028235  0.034855  0.009835
# color_IJ_colors     0.244366  0.034409  0.039905  0.130993  0.018424
# clarity_I1_clarity  0.117546  0.082706  0.041957 -0.002862  0.169628
# ...

# %%
print(len(d1[d1.clarity_S_clarity==1]),len(d1[d1.clarity_V_clarity==1]))
# Out:
# 16667 21862

# %%
d1.drop(columns=['clarity_S_clarity','cut',"color","clarity"],inplace=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
cols=["carat","depth","table"]
fig, axes = plt.subplots(3, figsize=(12,4))
for k,v in enumerate(cols):
    plt.sca(axes[k])
    sns.boxplot(d1[v],palette='pastel',showmeans=True)   
    #d1[v]=d1[v][d1[v].between(d1[v].quantile(.10), d1[v].quantile(.90))]

# %%
cols=["carat","depth","table"]
fig, axes = plt.subplots(3, figsize=(12,4))
for k,v in enumerate(cols):
    plt.sca(axes[k])
    sns.boxplot(d1[v],palette='pastel',showmeans=True)

# %%
d1.dropna(inplace=True)

# %%
d1
# Out:
#        carat  depth  table  price  cut_Fair  cut_Good  cut_Ideal  cut_Premium  \
# 0       2.26   61.9   57.0  12831         0         0          1            0
# 1       2.43   63.2   57.0  16170         0         0          0            0
# 2       0.80   61.0   57.0   2797         0         0          0            1
# 3       0.40   63.3   60.0    630         0         0          1            0
# 4       0.31   61.6   55.0    698         0         0          1            0
# ...      ...    ...    ...    ...       ...       ...        ...          ...
# 40450   1.11   62.8   61.0   5315         0         0          0            1
# 40451   0.73   62.6   56.0   2762         0         0          1            0
# 40452   1.26   59.2   60.0   6855         0         0          0            0
# 40453   0.72   61.4   56.0   2297         0         0          1            0
# 40454   0.54   60.8   59.0   1356         0         0          0            1
#
# ...

# %%
d1_menor=d1[d1['carat']<=car_50]
d1_mayor=d1[d1['carat']>car_50]

# %%
'''
y=d1['price']
c=list(d1.columns)
c.remove('price')
X=d1[c]
'''
y_menor=d1_menor['price']
c=list(d1.columns)
c.remove('price')
X_menor=d1_menor[c]
y_mayor=d1_mayor['price']
c=list(d1.columns)
c.remove('price')
X_mayor=d1_mayor[c]

# %%
print(X_mayor.shape,X_menor.shape)
# Out:
# (20097, 14) (20343, 14)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=10)
XReduced = pd.DataFrame(pca.fit_transform(X))

# %%
from sklearn.model_selection import train_test_split

X_train_mayor, X_test_mayor, y_train_mayor, y_test_mayor = train_test_split(X_mayor,y_mayor, test_size=0.2)
X_train_menor, X_test_menor, y_train_menor, y_test_menor = train_test_split(X_menor,y_menor, test_size=0.2)

# %%
from sklearn.ensemble import RandomForestRegressor
#n_estimators=250
regr_mayor = RandomForestRegressor(n_estimators=250)
res_mayor=regr_mayor.fit(X_train_mayor, y_train_mayor)
y_pred_test_mayor=regr_mayor.predict(X_test_mayor)

# %%
regr_menor = RandomForestRegressor(n_estimators=250)
res_menor=regr_menor.fit(X_train_menor,y_train_menor)
y_pred_test_menor=regr_menor.predict(X_test_menor)

# %%
from sklearn.model_selection import cross_val_score, KFold
kf = KFold(n_splits=2, shuffle=True, random_state=11)

# %%
import numpy as np
score_mayor=cross_val_score(regr_mayor, X_train_mayor, y_train_mayor, scoring='r2', cv=kf, n_jobs=2)
score_menor=cross_val_score(regr_menor, X_train_menor, y_train_menor, scoring='r2', cv=kf, n_jobs=2)
print(score_mayor,score_menor)
# Out:
# [0.91163281 0.90656889] [0.88950632 0.88971458]

# %%
print(np.mean(score_mayor),np.mean(score_menor))
# Out:
# 0.9091008489473497 0.8896104514767549

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
print(sqrt(mean_squared_error(y_pred_test_mayor, y_test_mayor)),sqrt(mean_squared_error(y_pred_test_menor, y_test_menor)))
# Out:
# 1185.17817818415 227.25648547096733

# %%
d_test=pd.read_csv("./input/test.csv")

# %%
d_test.drop(columns=['x','z'],inplace=True)
# Out:
#           id  carat      cut color clarity  depth  table     x     y     z
# 0          0   0.56    Ideal     I     VS2   62.1   54.0  5.30  5.33  3.30
# 1          1   1.05    Ideal     G     VS2   61.9   56.0  6.56  6.52  4.05
# 2          2   0.50  Premium     E     VS2   61.5   56.0  5.11  5.07  3.13
# 3          3   0.80    Ideal     F     VS1   62.8   56.0  5.91  5.96  3.73
# 4          4   0.54    Ideal     G     VS1   61.4   57.0  5.23  5.20  3.20
# ...      ...    ...      ...   ...     ...    ...    ...   ...   ...   ...
# 13480  13480   0.70  Premium     H     SI1   59.0   60.0  5.86  5.81  3.44
# 13481  13481   0.55    Ideal     G    VVS2   62.3   53.0  5.27  5.29  3.29
# 13482  13482   1.54    Ideal     G     SI1   61.5   55.0  7.40  7.45  4.57
# 13483  13483   0.30  Premium     G     SI2   62.7   55.0  4.29  4.26  2.68
# 13484  13484   0.42    Ideal     E    VVS2   61.3   56.0  4.85  4.81  2.96
#
# [13485 rows x 10 columns]

# %%
changes={"DE_colors":["D","E"],"FGH_colors": ["F","G","H"],"IJ_colors":["I","J"]}

d_test.color=d_test.color.apply(color_grouping)

changes={"I1_clarity":["I1"],"S_clarity": ["SI2", "SI1"], "V_clarity":["VS2", "VS1", "VVS2", "VVS1"], "IF_clarity":["IF"]}

d_test.clarity=d_test.clarity.apply(color_grouping)

# %%
dummies=d_test[['cut',"color","clarity"]]
d_dum=pd.get_dummies(dummies)
d_test=d_test.join(d_dum)
d_test
# Out:
#           id  carat      cut       color    clarity  depth  table     x     y  \
# 0          0   0.56    Ideal   IJ_colors  V_clarity   62.1   54.0  5.30  5.33
# 1          1   1.05    Ideal  FGH_colors  V_clarity   61.9   56.0  6.56  6.52
# 2          2   0.50  Premium   DE_colors  V_clarity   61.5   56.0  5.11  5.07
# 3          3   0.80    Ideal  FGH_colors  V_clarity   62.8   56.0  5.91  5.96
# 4          4   0.54    Ideal  FGH_colors  V_clarity   61.4   57.0  5.23  5.20
# ...      ...    ...      ...         ...        ...    ...    ...   ...   ...
# 13480  13480   0.70  Premium  FGH_colors  S_clarity   59.0   60.0  5.86  5.81
# 13481  13481   0.55    Ideal  FGH_colors  V_clarity   62.3   53.0  5.27  5.29
# 13482  13482   1.54    Ideal  FGH_colors  S_clarity   61.5   55.0  7.40  7.45
# 13483  13483   0.30  Premium  FGH_colors  S_clarity   62.7   55.0  4.29  4.26
# 13484  13484   0.42    Ideal   DE_colors  V_clarity   61.3   56.0  4.85  4.81
#
# ...

# %%
d_test.drop(columns=['clarity_S_clarity','cut',"color","clarity"],inplace=True)

# %%
d_test.drop(columns=['x',"z"],inplace=True)

# %%
test=d_test.drop(columns=['id'])

# %%
price_pred_test=regr.predict(test)

# %%
df=pd.DataFrame({'id':d_test['id'],
                'price':price_pred_test})
df
# Out:
#           id        price
# 0          0  1433.900000
# 1          1  7791.136000
# 2          2  1724.814667
# 3          3  3736.880000
# 4          4  1839.549333
# ...      ...          ...
# 13480  13480  2085.852000
# 13481  13481  1756.823333
# 13482  13482  4659.026000
# 13483  13483   876.784000
# 13484  13484  1083.020000
#
# [13485 rows x 2 columns]

# %%
df.to_csv("./output/res.csv",index=False)
